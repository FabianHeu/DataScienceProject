# %%
import pandas as pd
import numpy as np
import plotly.graph_objects as go

# %%
dataframeGlobal = pd.read_csv('../data/global_total.csv')
columnsGlobal = dataframeGlobal.columns
indexGlobal = dataframeGlobal.index

# %%
# print(columnsGlobal)

# %%
# dataframeGlobal['location'].unique()

# %%
dfNZ = dataframeGlobal[dataframeGlobal['location'] == 'Germany']
fig = go.Figure([go.Scatter(x=dfNZ['date'], y=dfNZ['people_fully_vaccinated'])])
fig.show()
# Out:
# <div>                            <div id="58956f2d-72cb-40b2-8bd6-63219fada90f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("58956f2d-72cb-40b2-8bd6-63219fada90f")) {                    Plotly.newPlot(                        "58956f2d-72cb-40b2-8bd6-63219fada90f",                        [{"x":["2020-01-27","2020-01-28","2020-01-29","2020-01-30","2020-01-31","2020-02-01","2020-02-02","2020-02-03","2020-02-04","2020-02-05","2020-02-06","2020-02-07","2020-02-08","2020-02-09","2020-02-10","2020-02-11","2020-02-12","2020-02-13","2020-02-14","2020-02-15","2020-02-16","2020-02-17","2020-02-18","2020-02-19","2020-02-20","2020-02-21","2020-02-22","2020-02-23","2020-02-24","2020-02-25","2020-02-26","2020-02-27","2020-02-28","2020-02-29","2020-03-01","2020-
# ...
